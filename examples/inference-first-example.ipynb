# %% [markdown]
# # Inference: First example
#
# This example shows you how to perform Bayesian inference on a time series, using [Adaptive Covariance MCMC](http://pints.readthedocs.io/en/latest/mcmc/adaptive_covariance_mcmc.html).
#
# It follows on from [Optimisation: First example](./optimisation-first-example.ipynb)
#
# Like in the optimisation example, we start by importing pints:

# %%
import pints

# %% [markdown]
# Next, we create a model class.
#
# Instead of using a real model, in this example we use the "Logistic" toy model included in pints:

# %%
import pints.toy as toy
model = toy.LogisticModel()

# %% [markdown]
# In order to generate some test data, we choose an arbitrary set of "true" parameters:

# %%
true_parameters = [0.015, 500]

# %% [markdown]
# And a number of time points at which to sample:

# %%
import numpy as np
times = np.linspace(0, 1000, 400)

# %% [markdown]
# Using these parameters and time points, we can now generate some toy data:

# %%
org_values = model.simulate(true_parameters, times)

# %% [markdown]
# And make it more realistic by adding gaussian noise:

# %%
noise = 25
values = org_values + np.random.normal(0, noise, org_values.shape)

# %% [markdown]
# We can use matplotlib (or any other plotting package) to look at the data we've created:

# %%
import matplotlib.pyplot as pl

pl.figure(figsize=(12,4.5))
pl.xlabel('Time')
pl.ylabel('Values')
pl.plot(times, values, label='Noisy data')
pl.plot(times, org_values, lw=2, label='Noise-free data')
pl.legend()
pl.show()

# %% [markdown]
# Now we have enough data (a model, a list of times, and a list of data) to formulate a problem:

# %%
problem = pints.SingleSeriesProblem(model, times, values)

# %% [markdown]
# We now have some toy data, and a model that can be used for forward simulations. To make it into a probabilistic problem, we need to add a _noise model_. One way to do this is using the `UnknownNoiseLogLikelihood` function, which assumes independently distributed Gaussian noise over the data, and can calculate log-likelihoods:

# %%
log_likelihood = pints.UnknownNoiseLogLikelihood(problem)

# %% [markdown]
# This noise has mean zero, and an unknown standard deviation. How can we find out the standard deviation? By inferring it along with the other parameters. This means we have added one parameter to our problem!

# %%
print('Original problem dimension: ' + str(problem.dimension()))
# Out:
# Original problem dimension: 2

# %%
print('New dimension: ' + str(log_likelihood.dimension()))
# Out:
# New dimension: 3

# %% [markdown]
# (This means we also have to update our vector of true parameters)

# %%
true_parameters += [noise]
print(true_parameters)
# Out:
# [0.015, 500, 25]

# %% [markdown]
# This `log_likelihood` represents the _conditional probability_ $p(y|\theta)$, given a set of parameters $\theta$ and a series of $y=$ `values`, it can calculate the probability of finding those values if the real parameters are $\theta$.
#
# We can use this in a Bayesian inference scheme to find the quantity we're interested in:
#
# $p(\theta|y) = \frac{p(\theta)p(y|\theta)}{p(y)} \propto p(\theta)p(y|\theta)$
#
# To solve this, we now define a _prior_, indicating our initial ideas about what the parameters should be. In this example we'll assume we don't know too much except lower and upper bounds for each variable: We assume the first model parameter is somewhere on the interval $[0.01, 0.02]$, the second model parameter on $[400, 600]$, and the standard deviation of the noise is somewhere on $[1, 100]$.

# %%
prior = pints.UniformPrior(
    [0.01, 400, 1],
    [0.02, 600, 100]
    )

# %% [markdown]
# With this prior, we can now define the numerator of Bayes' rule -- the unnormalised log posterior, $p(\theta)p(y|\theta)$

# %%
log_likelihood = pints.LogPosterior(prior, log_likelihood)

# %% [markdown]
# And this, together with a guess at the true parameters, gives us everything we need to run an MCMC routine:

# %%
x0 = np.array(true_parameters) * 1.1
chain = pints.adaptive_covariance_mcmc(log_likelihood, x0)
# Out:
# Running adaptive covariance MCMC
# Target acceptance rate: 0.25
# Total number of iterations: 6000
# Number of iterations before adapation: 1500
# Number of iterations to discard as burn-in: 3000
# Storing one sample per 1
# Iteration 0 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0
# Iteration 50 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0392156862745
# Iteration 100 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.029702970297
# Iteration 150 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0198675496689
# Iteration 200 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0149253731343
# Iteration 250 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0159362549801
# Iteration 300 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0166112956811
# Iteration 350 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.017094017094
# Iteration 400 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0149625935162
# Iteration 450 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0133037694013
# Iteration 500 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0139720558882
# Iteration 550 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0145190562613
# Iteration 600 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0149750415973
# Iteration 650 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0168970814132
# Iteration 700 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0156918687589
# Iteration 750 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0159786950732
# Iteration 800 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0162297128589
# Iteration 850 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0176263219741
# Iteration 900 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0166481687014
# Iteration 950 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0157728706625
# Iteration 1000 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.015984015984
# Iteration 1050 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0161750713606
# Iteration 1100 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.016348773842
# Iteration 1150 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0173761946134
# Iteration 1200 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0166527893422
# Iteration 1250 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0167865707434
# Iteration 1300 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0169100691776
# Iteration 1350 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0162842339008
# Iteration 1400 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0157030692363
# Iteration 1450 of 6000
#   In burn-in: True
#   Adapting: False
#   Acceptance rate: 0.0151619572708
# Iteration 1500 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0153231179214
# Iteration 1550 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0277240490006
# Iteration 1600 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0387257963773
# Iteration 1650 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0514839491217
# Iteration 1700 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0587889476778
# Iteration 1750 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0633923472302
# Iteration 1800 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0666296501943
# Iteration 1850 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0702323068612
# Iteration 1900 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0725933719095
# Iteration 1950 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0784213223988
# Iteration 2000 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0844577711144
# Iteration 2050 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0877620672843
# Iteration 2100 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0923369823893
# Iteration 2150 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0957694095769
# Iteration 2200 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.0976828714221
# Iteration 2250 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.100399822301
# Iteration 2300 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.103867883529
# Iteration 2350 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.107188430455
# Iteration 2400 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.11120366514
# Iteration 2450 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.115463076295
# Iteration 2500 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.117153138745
# Iteration 2550 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.119952959624
# Iteration 2600 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.122645136486
# Iteration 2650 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.123726895511
# Iteration 2700 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.125138837468
# Iteration 2750 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.126499454744
# Iteration 2800 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.129953588004
# Iteration 2850 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.132935811996
# Iteration 2900 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.135125818683
# Iteration 2950 of 6000
#   In burn-in: True
#   Adapting: True
#   Acceptance rate: 0.135886140291
# Iteration 3000 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.13728757081
# Iteration 3050 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.139298590626
# Iteration 3100 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.139954853273
# Iteration 3150 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.141225007934
# Iteration 3200 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.144329896907
# Iteration 3250 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.14580129191
# Iteration 3300 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.145713420176
# Iteration 3350 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.148313936138
# Iteration 3400 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.149073801823
# Iteration 3450 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.149811648797
# Iteration 3500 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.152813481862
# Iteration 3550 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.154604336807
# Iteration 3600 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.156623160233
# Iteration 3650 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.158312791016
# Iteration 3700 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.158875979465
# Iteration 3750 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.160223940283
# Iteration 3800 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.160220994475
# Iteration 3850 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.161516489224
# Iteration 3900 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.163291463727
# Iteration 3950 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.164515312579
# Iteration 4000 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.165458635341
# Iteration 4050 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.165638114046
# Iteration 4100 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.166544745184
# Iteration 4150 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.168152252469
# Iteration 4200 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.168293263509
# Iteration 4250 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.168666196189
# Iteration 4300 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.169727970239
# Iteration 4350 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.170535509078
# Iteration 4400 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.171551920018
# Iteration 4450 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.174567512918
# Iteration 4500 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.175072206176
# Iteration 4550 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.176884201274
# Iteration 4600 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.178439469681
# Iteration 4650 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.17931627607
# Iteration 4700 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.17847266539
# Iteration 4750 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.179120185224
# Iteration 4800 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.178504478234
# Iteration 4850 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.179756751185
# Iteration 4900 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.180575392777
# Iteration 4950 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.181377499495
# Iteration 5000 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.181363727255
# Iteration 5050 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.181350227678
# Iteration 5100 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.182317192707
# Iteration 5150 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.182294700058
# Iteration 5200 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.182272639877
# Iteration 5250 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.182822319558
# Iteration 5300 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.182795698925
# Iteration 5350 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.183517099608
# Iteration 5400 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.183114238104
# Iteration 5450 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.184553292974
# Iteration 5500 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.185057262316
# Iteration 5550 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.185912448208
# Iteration 5600 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.186930905196
# Iteration 5650 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.187046540435
# Iteration 5700 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.186809331696
# Iteration 5750 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.186402364806
# Iteration 5800 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.18634718152
# Iteration 5850 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.186976585199
# Iteration 5900 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.186748008812
# Iteration 5950 of 6000
#   In burn-in: False
#   Adapting: True
#   Acceptance rate: 0.18685935137

# %% [markdown]
# ## Using Pints' diagnostic plots to inspect the results
#
# We can take a further look at the obtained results using Pints's [diagnostic plots](http://pints.readthedocs.io/en/latest/diagnostic_plots.html).
#
# Now we can plot samples from the resulting markov chains to approximate the distributions of the parameters:

# %%
import pints.plot

fig, axes = pints.plot.histogram(chain)

# Show true value
for i, real in enumerate(true_parameters):
    axes[i].axvline(real)

# Show where the sample standard deviation of the generated noise is:
noise_sample_mean = np.mean(values - org_values)
noise_sample_std = np.std(values - org_values)
axes[i].axvline(noise_sample_std, color='orange')

fig.set_size_inches(14, 9)
pl.show()

# %% [markdown]
# As these plots show, we came pretty close to the original "true" values (represented by the blue line).
#
# But not exactly... Worse, the method seems to suggest a normal distribution but around the wrong point.
#
# To find out what's going on, we can plot the log-likelihood function near the true parameters:

# %%
# Plot log-likelihood function

fig, axes = pints.plot.log_likelihood_1d(log_likelihood, 
                                         true_parameters, 
                                         chain=chain, 
                                         n_eva=100)

# Add a line showing the sample standard deviation of the
# generated noise
axes[-1].axvline(noise_sample_std, color='orange', label='Sample std.')

fig.set_size_inches(14, 9)
pl.show()

# %% [markdown]
# As this plot (created entirely without MCMC!) shows, the MCMC method did well, but our estimate of the true parameters has become _biased_ by the stochastic noise! You can test this by increasing the number of sample points, which increases the size of the noise sample, and reduces the bias.

# %% [markdown]
# For example, to plot the histograms shown above, we could have used the [pairwise()](http://pints.readthedocs.io/en/latest/diagnostic_plots.html#pints.plot.pairwise) method. In addition to a histogram of each parameter, the pairwise plot also includes plots of pairwise parameter comparisons. These can be used to see if there are strong correlations between parameters.

# %%
pints.plot.pairwise(chain, kde=True)
pl.show()

# %% [markdown]
# Another way to inspect the results, is to take a number of samples from the chain, run new simulations using those parameters, and then compare the results with the real data (a _posterior predictive check_). This can be done using the [series()](http://pints.readthedocs.io/en/latest/diagnostic_plots.html#pints.plot.series) method.

# %%
fig, axes = pints.plot.series(chain, problem)

# Customise the plot, and add the original, noise-free data
fig.set_size_inches(12,4.5)
pl.plot(times, org_values, c='orange', label='Noise-free data')
pl.legend()
pl.show()

# %% [markdown]
# The [autocorrelation()](http://pints.readthedocs.io/en/latest/diagnostic_plots.html#pints.plot.autocorrelation) plot can be used to search for autocorrelation in the markov chain returned by the MCMC method. If everything went well, the samples in the chain should be relatively independent, so the autocorrelation should get quite low when the `lag` on the x-axis increases.

# %%
pints.plot.autocorrelation(chain)
pl.show()

# %% [markdown]
# Finally, we can inspect the _traces_ of the chains as they move through parameter space, by using the [trace()](http://pints.readthedocs.io/en/latest/diagnostic_plots.html#pints.plot.trace) method. This is particularly useful when we've run multiple MCMC routines, so we can compare them and see if they have converged to the same point.

# %%
# Run two more MCMC routines
# Instead of using pints.adaptive_covariance_mcmc(), here we're using the full
# pints.AdaptiveCovarianceMCMC so we can customise the routine and disable the
# printed output.
mcmc = pints.AdaptiveCovarianceMCMC(log_likelihood, x0)
mcmc.set_verbose(False)
chain2 = mcmc.run()
chain3 = mcmc.run()

# %% [markdown]
# Then we plot the traces of the chains.

# %%
pints.plot.trace(chain, chain2, chain3)
pl.show()
